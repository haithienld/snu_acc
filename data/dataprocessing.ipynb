# %%
import pandas as pd
import os
import shutil

# %%
# Read train data
df = pd.read_csv('annotations/val.csv',sep=' ',names=['fileName',"labelClass"], header=None)

# %%
annotations/train/camView1annotations/train/camView1df.loc[df['fileName'].str.contains('Dashboard') == True, 'cView'] = "1"
df.loc[df['fileName'].str.contains('Right') == True, 'cView'] = "2"
df.loc[df['fileName'].str.contains('Rear') == True, 'cView'] = "3"
# df.loc[df['video'].str.contains('Dashboard') = True, 'view']
# if(df["video"].str.contains('Right')):
#     df["view"] = 1
# if(df["video"].str.contains('Rear')):
#     df["view"] = 0

# %%
df
# Out:
#                                               fileName  labelClass cView
# 0    Rightside_window_user_id_24491_NoAudio_1.24491...           0     2
# 1    Rightside_window_user_id_24491_NoAudio_1.24491...           3     2
# 2    Rightside_window_user_id_24491_NoAudio_1.24491...          14     2
# 3    Rightside_window_user_id_24491_NoAudio_1.24491...           2     2
# 4    Rightside_window_user_id_24491_NoAudio_1.24491...           8     2
# ..                                                 ...         ...   ...
# 554  Right_window_user_id_49381_NoAudio_1.49381.401...          16     2
# 555  Right_window_user_id_49381_NoAudio_1.49381.435...          10     2
# 556  Right_window_user_id_49381_NoAudio_1.49381.461...           5     2
# 557  Right_window_user_id_49381_NoAudio_1.49381.488...          11     2
# 558  Right_window_user_id_49381_NoAudio_1.49381.513...           2     2
#
# [559 rows x 3 columns]

# %%
new = df['fileName'].str.split(".", n = 4, expand = True)

# %%
df["userID"] = new[1]
df["startTime"] = new[2]
df["endTime"] = new[3]

# %%
old_cols = df.columns.values 
old_cols
# Out:
# array(['fileName', 'labelClass', 'cView', 'userID', 'startTime',
#        'endTime'], dtype=object)

# %%
new_cols= ['fileName', 'startTime', 'endTime', 'userID','cView','labelClass']
df = df.reindex(columns=new_cols)

# %%
df
# Out:
#                                               fileName startTime endTime  \
# 0    Rightside_window_user_id_24491_NoAudio_1.24491...         0      17
# 1    Rightside_window_user_id_24491_NoAudio_1.24491...        18      45
# 2    Rightside_window_user_id_24491_NoAudio_1.24491...        45      54
# 3    Rightside_window_user_id_24491_NoAudio_1.24491...        74     105
# 4    Rightside_window_user_id_24491_NoAudio_1.24491...       113     117
# ..                                                 ...       ...     ...
# 554  Right_window_user_id_49381_NoAudio_1.49381.401...       401     425
# 555  Right_window_user_id_49381_NoAudio_1.49381.435...       435     451
# 556  Right_window_user_id_49381_NoAudio_1.49381.461...       461     478
# 557  Right_window_user_id_49381_NoAudio_1.49381.488...       488     503
# 558  Right_window_user_id_49381_NoAudio_1.49381.513...       513     535
#
#     userID cView  labelClass
# 0    24491     2           0
# 1    24491     2           3
# ...

# %%
g = df.groupby(['cView', df.labelClass])

# %%
import os

for (cView, labelClass), group in g:
    if not os.path.exists("camView"+str(cView)):
        os.makedirs("camView"+str(cView))
    group.iloc[:,:].to_csv(f'{"camView"+cView}/{labelClass}.csv', index=False)

# %%
# ground_truth["label_action"] = ground_truth["label_action"].map(lambda x: x.lstrip('MP4 ').rstrip(' '))

# %%
# change val = train 
# change camView3 = camView1 or camView2
for i in range(18):
    df = pd.read_csv("annotations/val/camView3/"+str(i)+".csv")
    directory = "annotations/val/camView3/" + str(i)
    if not os.path.exists(directory):
        os.makedirs(directory)
    for row in range(len(df)):
        source_file = os.path.join("A1_clips/"+str(df["fileName"][row]))
        dest_file = os.path.join(directory + "/" + str(df["fileName"][row]))
        shutil.copy(source_file, dest_file)
        print(dest_file)
# Out:
# annotations/val/camView3/0/Rear_view_user_id_24491_NoAudio_0.24491.0.120.MP4
# annotations/val/camView3/0/Rear_view_user_id_24491_NoAudio_0.24491.423.450.MP4
# annotations/val/camView3/0/Rear_view_user_id_24491_NoAudio_1.24491.0.17.MP4
# annotations/val/camView3/0/Rear_view_user_id_24491_NoAudio_1.24491.303.318.MP4
# annotations/val/camView3/0/Rear_view_User_id_24026_NoAudio_3.24026.0.7.MP4
# annotations/val/camView3/0/Rear_view_User_id_24026_NoAudio_3.24026.69.86.MP4
# annotations/val/camView3/0/Rear_view_User_id_24026_NoAudio_4.24026.0.22.MP4
# annotations/val/camView3/0/Rear_view_User_id_24026_NoAudio_4.24026.84.101.MP4
# annotations/val/camView3/0/Rear_view_User_id_24026_NoAudio_4.24026.547.579.MP4
# annotations/val/camView3/0/Rear_view_user_id_35133_NoAudio_0.35133.103.121.MP4
# annotations/val/camView3/0/Rear_view_user_id_35133_NoAudio_2.35133.41.58.MP4
# annotations/val/camView3/0/Rear_view_User_id_38058_NoAudio_0.38508.390.409.MP4
# ...

# %%
df = pd.read_csv("annotations/val/camView1/0.csv")
dest = "annotations/train/camView1/"
directory = "annotations/train/camView1/0"
if not os.path.exists(directory):
    os.makedirs(directory)
for row in range(len(df)):
    source_file = os.path.join("A1_clips/"+str(df["fileName"][row]))
    dest_file = os.path.join(directory + "/" + str(df["fileName"][row]))
    shutil.copy(source_file, dest_file)
    print(dest_file)

# %%
dest = "Script_Output" 

for _, row in df.iterrows():
    if row['location'] == both:
        source_file = os.path.join("My_videos",row['file_name'])
        dest_file = os.path.join(dest,row['file_name'])
        
        shutil.copy(source_file, dest_file)
    else:
        source_file = os.path.join("My_videos",row['file_name'])
        dest_file = os.path.join(dest,row['location'],row['file_name'])
        shutil.move(source_file, dest_file)
